# %% [markdown]
# https://projecteuler.net/problem=28
# ![image.png](attachment:68eef319-924f-421b-a40e-fbf3b0affd8b.png)

# %%
def compute_corner_sum(n):
    if n == 1:
        return 1
    else:
        return n**2 + n**2 - (n-1) + n**2 - 2*(n-1) + n**2 - 3*(n-1)

sum([compute_corner_sum(n) for n in range(1,1003,2)])
# Out:
# 669171000
