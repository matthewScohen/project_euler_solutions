# %% [markdown]
# https://projecteuler.net/problem=25
# ![image.png](attachment:5d2ad544-56db-414d-b832-ac874209883b.png)

# %%
a = 0
b = 1
term_count = 1
while len(str(b)) < 1000:
    next_term = a + b
    a = b
    b = next_term
    term_count += 1
print(term_count)
# Out:
# 4782
