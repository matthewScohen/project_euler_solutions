# %% [markdown]
# https://projecteuler.net/problem=29
# ![image.png](attachment:179c2e0c-1096-4a0b-8e89-1c0788eb50d2.png)

# %%
# %%time
def generate_combinations(a, b):
    for i in range(2, a+1):
        for j in range(2, b+1):
            yield i**j
len(set(generate_combinations(100,100)))
# Out:
# CPU times: user 7.91 ms, sys: 0 ns, total: 7.91 ms
# Wall time: 7.89 ms
# 9183
